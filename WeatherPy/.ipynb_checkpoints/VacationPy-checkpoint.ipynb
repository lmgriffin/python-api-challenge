# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

import warnings
warnings.filterwarnings("ignore")

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0           lebu -37.6167  -73.6500     10.04        79          85
# 1        1       thompson  55.7435  -97.8558     12.09        94         100
# 2        2    porto velho  -8.7619  -63.9039     30.03        66           0
# 3        3     codrington -38.2667  141.9667     11.91        77         100
# 4        4  blackmans bay -43.0167  147.3167     10.41        87          76
#
#    Wind Speed Country        Date
# 0        5.17      CL  1693259797
# 1        2.57      CA  1693259797
# 2        1.54      BR  1693259798
# 3        3.72      AU  1693259798
# 4        3.16      AU  1693259799

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
first_map = city_data_df.hvplot.points(
    "Lng", 
    "Lat", geo=True, 
    tiles = "OSM",
    color = "City",
    size = "Humidity"
)

# Display the map
first_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
narrow_data_df = city_data_df.loc[(city_data_df["Max Temp"] <= 26)&(city_data_df["Wind Speed"] <= 3)&(city_data_df["Humidity"] <= 70)]

# Drop any rows with null values
narrow_data_df.dropna(inplace=True)

# Display sample data
narrow_data_df.head()
# Out:
#     City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 11       11     qaqortoq  60.7167  -46.0333      9.32        58          63
# 20       20  sao vicente -23.9631  -46.3919     19.10        62          75
# 36       36  vilyuchinsk  52.9306  158.4028     12.15        70          51
# 49       49     ulaangom  49.9811   92.0667     19.00        40          68
# 56       56      quellon -43.1167  -73.6167     11.14        66          75
#
#     Wind Speed Country        Date
# 11        0.85      GL  1693259801
# 20        0.89      BR  1693259804
# 36        1.68      RU  1693259812
# 49        1.66      MN  1693259817
# 56        2.57      CL  1693259820

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = narrow_data_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head()
# Out:
#            City Country      Lat       Lng  Humidity Hotel Name
# 11     qaqortoq      GL  60.7167  -46.0333        58
# 20  sao vicente      BR -23.9631  -46.3919        62
# 36  vilyuchinsk      RU  52.9306  158.4028        70
# 49     ulaangom      MN  49.9811   92.0667        40
# 56      quellon      CL -43.1167  -73.6167        66

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories": "accommodation.hotel",
    "apiKey": geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    Longitude = row["Lng"]
    Latitude = row["Lat"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{Longitude},{Latitude},{radius}"
    params["bias"] = f"proximity:{Longitude},{Latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# qaqortoq - nearest hotel: Hotel Qaqortoq
# sao vicente - nearest hotel: Pousada Vitória
# vilyuchinsk - nearest hotel: Победа
# ulaangom - nearest hotel: АНДУУД
# quellon - nearest hotel: Aliwen
# oamaru - nearest hotel: Brydone Hotel Oamaru
# bilibino - nearest hotel: No hotel found
# gwaram - nearest hotel: No hotel found
# bredasdorp - nearest hotel: Victoria Hotel
# kandyagash - nearest hotel: No hotel found
# saurimo - nearest hotel: Complexo Hoteleiro de Saurimo
# saint-pierre - nearest hotel: Tropic Hotel
# nishon tumani - nearest hotel: Жура ота
# vallenar - nearest hotel: Hotel del Marqués
# castilho - nearest hotel: No hotel found
# al bayda' - nearest hotel: فندق الهديل
# abasolo - nearest hotel: Hotel La Caldera
# mossel bay - nearest hotel: Protea Hotel Mossel Bay
# san julian - nearest hotel: No hotel found
# qarqin - nearest hotel: No hotel found
# pont rouge - nearest hotel: No hotel found
# zeya - nearest hotel: Серебряный створ
# sao desiderio - nearest hotel: No hotel found
# uacu cungo - nearest hotel: Ritz Waku Kungu
# gisborne - nearest hotel: Portside Hotel
# zarghun shahr - nearest hotel: No hotel found
# tosontsengel - nearest hotel: Алтай
# kutum - nearest hotel: No hotel found
# khenifra - nearest hotel: Najah
# sevastopol - nearest hotel: Барабулька
# port hedland - nearest hotel: The Esplanade Hotel
# kone - nearest hotel: Pacifik Appartels
# pontiac - nearest hotel: Hampton Inn & Suites
# ushtobe - nearest hotel: No hotel found
# gutao - nearest hotel: Yufengheng
# marquetalia - nearest hotel: No hotel found
# maumere - nearest hotel: Bogor
# uvinza - nearest hotel: Mapito lodge
# presidente olegario - nearest hotel: No hotel found
# happy valley-goose bay - nearest hotel: Hotel North Two
# campbell river - nearest hotel: Comfort Inn & Suites
# timaru - nearest hotel: The Grosvenor Hotel
# mount isa - nearest hotel: Ibis Styles
# queenstown - nearest hotel: Queens Hotel
# carapegua - nearest hotel: CORONA SUITES
# edmundston - nearest hotel: Station 127
# okhotsk - nearest hotel: No hotel found
# ust-nera - nearest hotel: гостиница "Солнечная"
# kriel - nearest hotel: No hotel found
# mil'kovo - nearest hotel: Дрозды
# blenheim - nearest hotel: Chateau Marlborough
# tshikapa - nearest hotel: Hôtel TSHAMUNTU
# la puebla de montalban - nearest hotel: Hostal Dorado
# wuwei - nearest hotel: Hepingli Boutique Hotel
# argo - nearest hotel: Apollon Hotel
# slave lake - nearest hotel: Northwest Inn
#                        City Country      Lat       Lng  Humidity  \
# 11                 qaqortoq      GL  60.7167  -46.0333        58
# 20              sao vicente      BR -23.9631  -46.3919        62
# 36              vilyuchinsk      RU  52.9306  158.4028        70
# 49                 ulaangom      MN  49.9811   92.0667        40
# 56                  quellon      CL -43.1167  -73.6167        66
# 77                   oamaru      NZ -45.0784  170.9801        64
# 102                bilibino      RU  68.0546  166.4372        63
# 139                  gwaram      NG  11.2764    9.8858        70
# 143              bredasdorp      ZA -34.5322   20.0403        69
# 154              kandyagash      KZ  49.4744   57.4233        65
# 159                 saurimo      AO  -9.6608   20.3916        22
# 170            saint-pierre      RE -21.3393   55.4781        68
# 174           nishon tumani      UZ  38.6940   65.6751        41
# 176                vallenar      CL -28.5708  -70.7581        23
# 178                castilho      BR -20.8722  -51.4875        47
# 187               al bayda'      LY  32.7627   21.7551        41
# 201                 abasolo      MX  20.4500 -101.5167        50
# 210              mossel bay      ZA -34.1831   22.1460        67
# 236              san julian      MX  21.0167 -102.1667        48
# 243                  qarqin      AF  37.4185   66.0436        17
# 244              pont rouge      CA  48.8833  -72.0825        65
# 246                    zeya      RU  53.7500  127.2667        68
# 247           sao desiderio      BR -12.3633  -44.9733        63
# 265              uacu cungo      AO -11.3634   15.1208        43
# 266                gisborne      NZ -38.6533  178.0042        47
# 270           zarghun shahr      AF  32.8473   68.4457        24
# 280            tosontsengel      MN  48.7567   98.2839        66
# 288                   kutum      SD  14.2000   24.6667        54
# 295                khenifra      MA  32.9333   -5.6667        19
# 297              sevastopol      UA  44.6000   33.5333        55
# 300            port hedland      AU -20.3167  118.5667        47
# 306                    kone      NC -21.0595  164.8658        61
# 344                 pontiac      US  42.6389  -83.2911        46
# 348                 ushtobe      KZ  45.2514   77.9838        58
# 352                   gutao      CN  37.2025  112.1781        63
# 371             marquetalia      CO   5.2966  -75.0550        47
# 373                 maumere      ID  -8.6199  122.2111        67
# 377                  uvinza      TZ  -5.1036   30.3911        32
# 382     presidente olegario      BR -18.4178  -46.4181        61
# 392  happy valley-goose bay      CA  53.3168  -60.3315        43
# 395          campbell river      CA  50.0163 -125.2446        53
# 396                  timaru      NZ -44.4000  171.2500        44
# 404               mount isa      AU -20.7333  139.5000        62
# 417              queenstown      ZA -31.8976   26.8753        25
# 427               carapegua      PY -25.8000  -57.2333        49
# 432              edmundston      CA  47.3737  -68.3251        41
# 470                 okhotsk      RU  59.3833  143.3000        62
# 477                ust-nera      RU  64.5667  143.2000        57
# 505                   kriel      ZA -26.2739   29.2253        50
# 506                mil'kovo      RU  55.6078   37.7956        56
# 514                blenheim      NZ -41.5160  173.9528        68
# 526                tshikapa      CD  -6.4167   20.8000        46
# 533  la puebla de montalban      ES  39.8630   -4.3592        33
# 544                   wuwei      CN  37.9281  102.6414        48
# 552                    argo      GR  37.6333   22.7333        55
# 553              slave lake      CA  55.2834 -114.7690        56
#
#                         Hotel Name
# 11                  Hotel Qaqortoq
# 20                 Pousada Vitória
# 36                          Победа
# 49                          АНДУУД
# 56                          Aliwen
# 77            Brydone Hotel Oamaru
# 102                 No hotel found
# 139                 No hotel found
# 143                 Victoria Hotel
# 154                 No hotel found
# 159  Complexo Hoteleiro de Saurimo
# 170                   Tropic Hotel
# 174                       Жура ота
# 176              Hotel del Marqués
# 178                 No hotel found
# 187                    فندق الهديل
# 201               Hotel La Caldera
# 210        Protea Hotel Mossel Bay
# 236                 No hotel found
# 243                 No hotel found
# 244                 No hotel found
# 246               Серебряный створ
# 247                 No hotel found
# 265                Ritz Waku Kungu
# 266                 Portside Hotel
# 270                 No hotel found
# 280                          Алтай
# 288                 No hotel found
# 295                          Najah
# 297                     Барабулька
# 300            The Esplanade Hotel
# 306              Pacifik Appartels
# 344           Hampton Inn & Suites
# 348                 No hotel found
# 352                     Yufengheng
# 371                 No hotel found
# 373                          Bogor
# 377                   Mapito lodge
# 382                 No hotel found
# 392                Hotel North Two
# 395           Comfort Inn & Suites
# 396            The Grosvenor Hotel
# 404                    Ibis Styles
# 417                   Queens Hotel
# 427                  CORONA SUITES
# 432                    Station 127
# 470                 No hotel found
# 477          гостиница "Солнечная"
# 505                 No hotel found
# 506                         Дрозды
# 514            Chateau Marlborough
# 526                Hôtel TSHAMUNTU
# 533                  Hostal Dorado
# 544        Hepingli Boutique Hotel
# 552                  Apollon Hotel
# 553                  Northwest Inn

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
second_map = hotel_df.hvplot.points(
    "Lng", 
    "Lat", geo=True, 
    tiles = "OSM",
    color = "City",
    size = "Humidity",
    hover_cols = ["Country", "Hotel Name"]
)

# Display the map
second_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Country,Hotel Name)
